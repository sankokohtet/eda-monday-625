# %% [markdown]
# # Introduction to Python and Jupyter Notebooks
#
# To begin, be sure you understand how to move between cells in a Jupyter notebook and change them from code to markdown.  If you want additional work with styling markdown cells, please see the [cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).  In this part of the notebook, we will review some numpy basics and create some simple plots with Matplotlib.

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/T8JGn4JRy4g?ecver=1" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/T8JGn4JRy4g?ecver=1" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### NumPy and Matplotlib
#
# To begin, let's play with some basic `matplotlib` plots and the NumPy random methods. For more information please consult the documentation [here](https://docs.scipy.org/doc/numpy-1.14.0/reference/routines.random.html).

# %%
a = np.random.randint(1, 20, 100)

# %%
plt.figure()
plt.hist(a)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([10.,  9., 16., 10.,  8.,  5.,  8.,  7., 17., 10.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]),
#  <a list of 10 Patch objects>)

# %%
b = np.random.random(100)
c = np.random.normal(5, 10, 100)
d = np.random.binomial(100, .3, 100)

# %%
np.random.binomial?

# %%
a[:5]
# Out:
# array([13,  6,  6,  7,  7])

# %%
plt.figure(figsize = (9, 6))

plt.subplot(2, 2, 1)
plt.hist(a)
plt.title("Random Integers")

plt.subplot(2, 2, 2)
plt.hist(b, color = 'green')
plt.title("Random Floats")

plt.subplot(2, 2, 3)
plt.hist(c, color = 'grey')
plt.title("Normal Distribution")

plt.subplot(2, 2, 4)
plt.hist(d, color = 'orange')
plt.title("Binomial Distribution")
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0.5,1,'Binomial Distribution')

# %%
plt.figure()
plt.scatter(c, d)
plt.title("Scatter Plot", loc = 'left')
plt.xticks([])
plt.yticks([])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([], <a list of 0 Text yticklabel objects>)

# %%
dists = [a, b, c, d]
plt.figure()
plt.boxplot(dists)
plt.title("Boxplots of Distributions", loc = "right")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(1,1,'Boxplots of Distributions')

# %%
import seaborn as sns

plt.figure()
for i in [a,c,d]:
    sns.distplot(i, hist = False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Loading Data: Intro to Pandas
#
# Now, we use the Pandas library to examine a variety of datasets.  Below, I create four different `DataFrame` objects from files.  The first three are from `.csv` files located in our **data** directory.  The final, is through the API from NYCOpenData.  We will continue to visit methods of accessing and structuring data, but to begin we use these two popular options.
#
# To load the `.csv` files, we provide Pandas with a path or url in the `.read_csv()` method.  I load all four datasets in what follows.

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9Dsg9DQAU_g?ecver=1" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9Dsg9DQAU_g?ecver=1" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %%
nyc311data = pd.read_json('https://data.cityofnewyork.us/resource/fhrw-4uyv.json')
drones = pd.read_csv('../data/drones.csv', encoding = "utf8")
ozone = pd.read_csv('../data/ozone.csv')
titanic = pd.read_csv('../data/titanic.csv')

# %%
nyc311data.columns
# Out:
# Index([':@computed_region_92fq_4b7q', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        'address_type', 'agency', 'agency_name', 'borough',
#        'bridge_highway_segment', 'city', 'closed_date', 'community_board',
#        'complaint_type', 'created_date', 'cross_street_1', 'cross_street_2',
#        'descriptor', 'due_date', 'facility_type', 'ferry_terminal_name',
#        'incident_address', 'incident_zip', 'intersection_street_1',
#        'intersection_street_2', 'latitude', 'location', 'location_type',
#        'longitude', 'park_borough', 'park_facility_name',
#        'resolution_action_updated_date', 'resolution_description',
#        'school_address', 'school_city', 'school_code', 'school_name',
#        'school_not_found', 'school_number', 'school_phone_number',
#        'school_region', 'school_state', 'school_zip', 'status', 'street_name',
#        'taxi_company_borough', 'taxi_pick_up_location', 'unique_key',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane'],
#       dtype='object')

# %%
nyc311data.dtypes
# Out:
# :@computed_region_92fq_4b7q       float64
# :@computed_region_efsh_h5xi       float64
# :@computed_region_f5dn_yrer       float64
# :@computed_region_yeji_bk3q       float64
# address_type                       object
# agency                             object
# agency_name                        object
# borough                            object
# bridge_highway_segment             object
# city                               object
# closed_date                        object
# community_board                    object
# complaint_type                     object
# created_date                       object
# cross_street_1                     object
# cross_street_2                     object
# descriptor                         object
# due_date                           object
# facility_type                      object
# ferry_terminal_name                object
# incident_address                   object
# incident_zip                      float64
# intersection_street_1              object
# intersection_street_2              object
# latitude                          float64
# location                           object
# location_type                      object
# longitude                         float64
# park_borough                       object
# park_facility_name                 object
# resolution_action_updated_date     object
# resolution_description             object
# school_address                     object
# school_city                        object
# school_code                        object
# school_name                        object
# school_not_found                   object
# school_number                      object
# school_phone_number                object
# school_region                      object
# school_state                       object
# school_zip                         object
# status                             object
# street_name                        object
# taxi_company_borough               object
# taxi_pick_up_location              object
# unique_key                          int64
# x_coordinate_state_plane          float64
# y_coordinate_state_plane          float64
# dtype: object

# %%
nyc311data.describe()
# Out:
#        :@computed_region_92fq_4b7q  :@computed_region_efsh_h5xi  \
# count                   950.000000                   949.000000
# mean                     28.796842                 14795.075869
# std                      14.581474                  3637.065419
# min                       1.000000                 10092.000000
# 25%                      17.000000                 11723.000000
# 50%                      29.000000                 13515.000000
# 75%                      42.000000                 17216.000000
# max                      51.000000                 24671.000000
#
#        :@computed_region_f5dn_yrer  :@computed_region_yeji_bk3q  incident_zip  \
# count                   950.000000                   950.000000    956.000000
# mean                     35.560000                     3.151579  10838.580544
# std                      20.948632                     1.208580    543.359591
# min                       1.000000                     1.000000   7114.000000
# 25%                      16.250000                     2.000000  10453.000000
# 50%                      36.000000                     3.000000  11208.000000
# 75%                      54.000000                     4.000000  11230.000000
# max                      71.000000                     5.000000  11694.000000
#
#          latitude   longitude    unique_key  x_coordinate_state_plane  \
# count  950.000000  950.000000  1.000000e+03              9.500000e+02
# mean    40.729644  -73.927620  3.874951e+07              1.004302e+06
# std      0.089521    0.070968  2.144728e+03              1.967819e+04
# min     40.523806  -74.211054  3.874576e+07              9.255990e+05
# 25%     40.659393  -73.966430  3.874760e+07              9.935580e+05
# 50%     40.710720  -73.936934  3.874954e+07              1.001704e+06
# 75%     40.819868  -73.890401  3.875135e+07              1.014611e+06
# max     40.911842  -73.713145  3.875317e+07              1.063750e+06
#
#        y_coordinate_state_plane
# count                950.000000
# mean              205121.818947
# std                32615.490071
# min               130177.000000
# 25%               179519.250000
# 50%               198235.000000
# 75%               237982.250000
# max               271503.000000

# %%
complaints = nyc311data[['complaint_type', 'borough', 'agency', 'agency_name']]

# %%
complaints.head()
# Out:
#         complaint_type   borough agency  \
# 0         Damaged Tree  BROOKLYN    DPR
# 1     Blocked Driveway    QUEENS   NYPD
# 2      Illegal Parking  BROOKLYN   NYPD
# 3   Food Establishment     BRONX  DOHMH
# 4  Noise - Residential    QUEENS   NYPD
#
#                                agency_name
# 0       Department of Parks and Recreation
# 1          New York City Police Department
# 2          New York City Police Department
# 3  Department of Health and Mental Hygiene
# 4          New York City Police Department

# %%
complaints.groupby(by = 'borough').size()
# Out:
# borough
# BRONX            188
# BROOKLYN         367
# MANHATTAN        196
# QUEENS           192
# STATEN ISLAND     28
# Unspecified       29
# dtype: int64

# %%
complaints[complaints['borough'] =='BROOKLYN'].sort_values('complaint_type')[:10]
# Out:
#        complaint_type   borough agency  \
# 277         APPLIANCE  BROOKLYN    HPD
# 786         APPLIANCE  BROOKLYN    HPD
# 560       Air Quality  BROOKLYN    DEP
# 69       Animal Abuse  BROOKLYN   NYPD
# 253      Animal Abuse  BROOKLYN   NYPD
# 287      Animal Abuse  BROOKLYN   NYPD
# 809      Animal Abuse  BROOKLYN   NYPD
# 502  Animal in a Park  BROOKLYN    DPR
# 557  Blocked Driveway  BROOKLYN   NYPD
# 540  Blocked Driveway  BROOKLYN   NYPD
#
#                                            agency_name
# 277  Department of Housing Preservation and Develop...
# 786  Department of Housing Preservation and Develop...
# 560             Department of Environmental Protection
# 69                     New York City Police Department
# 253                    New York City Police Department
# 287                    New York City Police Department
# 809                    New York City Police Department
# 502                 Department of Parks and Recreation
# 557                    New York City Police Department
# 540                    New York City Police Department

# %%
BK_COMPLAIN = complaints[complaints['borough'] == 'BROOKLYN']['complaint_type'].value_counts()

# %%
plt.figure(figsize = (7, 5))
plt.bar(BK_COMPLAIN.index[:6], BK_COMPLAIN[:6])
# Out:
# <img src="data:image/png;base64,..." width="700">
# <Container object of 6 artists>

# %%
plt.tick_params(labelrotation = 20)

# %%
plt.figure(figsize = (9, 7))
bars = plt.barh(BK_COMPLAIN.index[:5], BK_COMPLAIN[:5])
plt.title("Top 5 311 Complaints in Brooklyn", loc = 'left', fontsize = 12)
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0,1,'Top 5 311 Complaints in Brooklyn')

# %%
labels = BK_COMPLAIN.index

# %%
for i in labels[:6]:
    print(i)
# Out:
# HEAT/HOT WATER
# Damaged Tree
# Noise - Residential
# Blocked Driveway
# Illegal Parking
# Traffic Signal Condition

# %%
for i in range(5):
    label = labels[i]
    plt.gca().text(2, i, label, color = 'w', fontsize = 10)

# %%
plt.tick_params(top = 'off', bottom = 'off', left = 'off', right = 'off', labelleft='off', labelbottom='off')

# %%
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %% [markdown]
# ### Titanic Manipulation

# %%
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic[titanic.pclass == 3][:5]
# Out:
#    survived  pclass                            name     sex   age  sibsp  \
# 0         0       3         Braund, Mr. Owen Harris    male  22.0      1
# 2         1       3          Heikkinen, Miss. Laina  female  26.0      0
# 4         0       3        Allen, Mr. William Henry    male  35.0      0
# 5         0       3                Moran, Mr. James    male   NaN      0
# 7         0       3  Palsson, Master. Gosta Leonard    male   2.0      3
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 7      1            349909  21.0750   NaN        S

# %%
titanic.sample(frac=0.1)[:5]
# Out:
#      survived  pclass                                name   sex   age  sibsp  \
# 553         1       3   Leeni, Mr. Fahim ("Philip Zenni")  male  22.0      0
# 90          0       3                Christmann, Mr. Emil  male  29.0      0
# 170         0       1           Van der hoef, Mr. Wyckoff  male  61.0      0
# 267         1       3            Persson, Mr. Ernst Ulrik  male  25.0      1
# 59          0       3  Goodwin, Master. William Frederick  male  11.0      5
#
#      parch   ticket    fare cabin embarked
# 553      0     2620   7.225   NaN        C
# 90       0   343276   8.050   NaN        S
# 170      0   111240  33.500   B19        S
# 267      0   347083   7.775   NaN        S
# 59       2  CA 2144  46.900   NaN        S

# %%
titanic.iloc[4:10]
# Out:
#    survived  pclass                                               name  \
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked
# 4    male  35.0      0      0  373450   8.0500   NaN        S
# 5    male   NaN      0      0  330877   8.4583   NaN        Q
# 6    male  54.0      0      0   17463  51.8625   E46        S
# 7    male   2.0      3      1  349909  21.0750   NaN        S
# 8  female  27.0      0      2  347742  11.1333   NaN        S
# 9  female  14.0      1      0  237736  30.0708   NaN        C

# %%
titanic.nlargest(10, 'age')
# Out:
#      survived  pclass                                  name   sex   age  \
# 630         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851         0       3                   Svensson, Mr. Johan  male  74.0
# 96          0       1             Goldschmidt, Mr. George B  male  71.0
# 493         0       1               Artagaveytia, Mr. Ramon  male  71.0
# 116         0       3                  Connors, Mr. Patrick  male  70.5
# 672         0       2           Mitchell, Mr. Henry Michael  male  70.0
# 745         0       1          Crosby, Capt. Edward Gifford  male  70.0
# 33          0       2                 Wheadon, Mr. Edward H  male  66.0
# 54          0       1        Ostby, Mr. Engelhart Cornelius  male  65.0
# 280         0       3                      Duane, Mr. Frank  male  65.0
#
#      sibsp  parch      ticket     fare cabin embarked
# 630      0      0       27042  30.0000   A23        S
# 851      0      0      347060   7.7750   NaN        S
# 96       0      0    PC 17754  34.6542    A5        C
# 493      0      0    PC 17609  49.5042   NaN        C
# 116      0      0      370369   7.7500   NaN        Q
# 672      0      0  C.A. 24580  10.5000   NaN        S
# 745      1      1   WE/P 5735  71.0000   B22        S
# 33       0      0  C.A. 24579  10.5000   NaN        S
# 54       0      1      113509  61.9792   B30        C
# 280      0      0      336439   7.7500   NaN        Q

# %%
titanic.nsmallest(10, 'age')
# Out:
#      survived  pclass                             name     sex   age  sibsp  \
# 803         1       3  Thomas, Master. Assad Alexander    male  0.42      0
# 755         1       2        Hamalainen, Master. Viljo    male  0.67      1
# 469         1       3    Baclini, Miss. Helene Barbara  female  0.75      2
# 644         1       3           Baclini, Miss. Eugenie  female  0.75      2
# 78          1       2    Caldwell, Master. Alden Gates    male  0.83      0
# 831         1       2  Richards, Master. George Sibley    male  0.83      1
# 305         1       1   Allison, Master. Hudson Trevor    male  0.92      1
# 164         0       3     Panula, Master. Eino Viljami    male  1.00      4
# 172         1       3     Johnson, Miss. Eleanor Ileen  female  1.00      1
# 183         1       2        Becker, Master. Richard F    male  1.00      2
#
#      parch   ticket      fare    cabin embarked
# 803      1     2625    8.5167      NaN        C
# 755      1   250649   14.5000      NaN        S
# 469      1     2666   19.2583      NaN        C
# 644      1     2666   19.2583      NaN        C
# 78       2   248738   29.0000      NaN        S
# 831      1    29106   18.7500      NaN        S
# 305      2   113781  151.5500  C22 C26        S
# 164      1  3101295   39.6875      NaN        S
# 172      1   347742   11.1333      NaN        S
# 183      1   230136   39.0000       F4        S

# %%
gender = titanic[['survived', 'sex']]

# %%
gender[gender['survived'] == 0].groupby('sex').size()
# Out:
# sex
# female     81
# male      468
# dtype: int64

# %%
gender[gender['survived'] == 1].groupby('sex').size()
# Out:
# sex
# female    233
# male      109
# dtype: int64
